# %% [markdown]
# # 01 — Download NASA POWER dataRuns `src/download_power.py` to fetch daily data (2005–2024) for the five study sites. NASA POWER requires no registration.Run in a terminal instead if preferred: `python src/download_power.py`

# %%
import sys; sys.path.append('../src')
from config import *  # sites, parameters, paths
