# %% [markdown]
# # 01 — Download NASA POWER data
#
# Runs `src/download_power.py` to fetch daily data (2005–2024) for the five study sites. NASA POWER requires no registration.
#
# Run in a terminal instead if preferred: `python src/download_power.py`
#
# *Status: completed 2026-07-13 — see `data/raw/download_log.txt` for row counts and SHA-256 digests.*

# %%
import sys; sys.path.append('../src')
from config import *  # sites, parameters, paths
